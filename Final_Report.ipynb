# %% [markdown]
# <img src="https://1000logos.net/wp-content/uploads/2017/11/Zillow-Logo.png" title="Zillow Logo"/>

# %% [markdown]
# <center> <h1>PREDICTING AND IMPROVING THE MEDIAN MARGIN OF ERROR FOR ZESTIMATES</h1>

# %% [markdown]
# By: Jennifer Eyring, Jemison cohort
#
# Date: June 20, 2022

# %% [markdown]
# # Introduction:
# In response to Zillow's data science team looking for new ways to improve the current median margin of error predictor model on property values, I have taken time to conduct some steps of applying unstructured ML models through clustering methods in attempts to find if this approach was best fit of predicting the log errors in Zillow's 2017 database.
#
# The following notebook provides a guide and breakdown of my process in setting up the unstructured ML models, by utilizing the data science pipeline.
#
# The reader will find step-by-step approaches to not only the process of which I followed, but also the included README.md file that gives more resources on how to implement the datasets and functions so that one can replicate and explore on the data themselves.

# %%
# ignore warnings
import warnings
warnings.filterwarnings("ignore")
import wrangle
import model

import pandas as pd
pd.options.display.max_rows = 100

import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

from scipy import stats
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.cluster import KMeans
from sklearn.metrics import mean_squared_error, r2_score, explained_variance_score
from sklearn.linear_model import LinearRegression, LassoLars, TweedieRegressor
from sklearn.preprocessing import PolynomialFeatures
from sklearn.feature_selection import RFE

# %% [markdown]
# >## Acquiring data through wrangle.py

# %%
df=wrangle.get_zillow_data()

# %% [markdown]
# >## Defining the dataset

# %%
#seeing what dataset looks like
wrangle.df_summary(df)
# Out:
# ---Shape: (52319, 68)
#
# ---Info
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52319 entries, 0 to 52318
# Data columns (total 68 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   id                            52319 non-null  int64
#  1   parcelid                      52319 non-null  int64
#  2   airconditioningtypeid         13615 non-null  float64
#  3   architecturalstyletypeid      70 non-null     float64
#  4   basementsqft                  47 non-null     float64
#  5   bathroomcnt                   52319 non-null  float64
#  6   bedroomcnt                    52319 non-null  float64
#  7   buildingclasstypeid           0 non-null      float64
#  8   buildingqualitytypeid         33654 non-null  float64
#  9   calculatedbathnbr             52184 non-null  float64
#  10  decktypeid                    389 non-null    float64
#  11  finishedfloor1squarefeet      4371 non-null   float64
#  12  calculatedfinishedsquarefeet  52238 non-null  float64
#  13  finishedsquarefeet12          52073 non-null  float64
#  14  finishedsquarefeet13          0 non-null      float64
#  15  finishedsquarefeet15          0 non-null      float64
#  16  finishedsquarefeet50          4371 non-null   float64
#  17  finishedsquarefeet6           165 non-null    float64
#  18  fips                          52319 non-null  float64
#  19  fireplacecnt                  7233 non-null   float64
#  20  fullbathcnt                   52184 non-null  float64
#  21  garagecarcnt                  17984 non-null  float64
#  22  garagetotalsqft               17984 non-null  float64
#  23  hashottuborspa                1514 non-null   float64
#  24  heatingorsystemtypeid         33849 non-null  float64
#  25  latitude                      52319 non-null  float64
#  26  longitude                     52319 non-null  float64
#  27  lotsizesquarefeet             51953 non-null  float64
#  28  poolcnt                       11077 non-null  float64
#  29  poolsizesum                   865 non-null    float64
#  30  pooltypeid10                  443 non-null    float64
#  31  pooltypeid2                   1071 non-null   float64
#  32  pooltypeid7                   9990 non-null   float64
#  33  propertycountylandusecode     52319 non-null  object
#  34  propertylandusetypeid         52319 non-null  float64
#  35  propertyzoningdesc            33761 non-null  object
#  36  rawcensustractandblock        52319 non-null  float64
#  37  regionidcity                  51283 non-null  float64
#  38  regionidcounty                52319 non-null  float64
#  39  regionidneighborhood          18981 non-null  float64
#  40  regionidzip                   52293 non-null  float64
#  41  roomcnt                       52319 non-null  float64
#  42  storytypeid                   47 non-null     float64
#  43  threequarterbathnbr           6717 non-null   float64
#  44  typeconstructiontypeid        76 non-null     float64
#  45  unitcnt                       33761 non-null  float64
#  46  yardbuildingsqft17            1935 non-null   float64
#  47  yardbuildingsqft26            63 non-null     float64
#  48  yearbuilt                     52205 non-null  float64
#  49  numberofstories               14532 non-null  float64
#  50  fireplaceflag                 81 non-null     float64
#  51  structuretaxvaluedollarcnt    52237 non-null  float64
#  52  taxvaluedollarcnt             52318 non-null  float64
#  53  assessmentyear                52319 non-null  float64
#  54  landtaxvaluedollarcnt         52318 non-null  float64
#  55  taxamount                     52315 non-null  float64
#  56  taxdelinquencyflag            2068 non-null   object
#  57  taxdelinquencyyear            2068 non-null   float64
#  58  censustractandblock           52198 non-null  float64
#  59  logerror                      52319 non-null  float64
#  60  transactiondate               52319 non-null  object
#  61  airconditioningdesc           13615 non-null  object
#  62  architecturalstyledesc        70 non-null     object
#  63  buildingclassdesc             0 non-null      float64
#  64  heatingorsystemdesc           33849 non-null  object
#  65  propertylandusedesc           52319 non-null  object
#  66  storydesc                     47 non-null     object
#  67  typeconstructiondesc          76 non-null     object
# dtypes: float64(56), int64(2), object(10)
# memory usage: 27.1+ MB
#
# --- Column Description
#                   id      parcelid  airconditioningtypeid  \
# count   5.231900e+04  5.231900e+04           13615.000000
# unique           NaN           NaN                    NaN
# top              NaN           NaN                    NaN
# freq             NaN           NaN                    NaN
# mean    1.496888e+06  1.299682e+07               2.439589
# std     8.594310e+05  3.350951e+06               3.847925
# min     3.490000e+02  1.071186e+07               1.000000
# 25%     7.575810e+05  1.151017e+07               1.000000
# 50%     1.500095e+06  1.257825e+07               1.000000
# 75%     2.241248e+06  1.413036e+07               1.000000
# max     2.982270e+06  1.676878e+08              13.000000
#
#         architecturalstyletypeid  basementsqft   bathroomcnt    bedroomcnt  \
# count                   70.00000     47.000000  52319.000000  52319.000000
# unique                       NaN           NaN           NaN           NaN
# top                          NaN           NaN           NaN           NaN
# freq                         NaN           NaN           NaN           NaN
# mean                     7.10000    678.978723      2.300015      3.300770
# std                      2.66567    711.825226      1.022816      0.947563
# min                      2.00000     38.000000      0.000000      0.000000
# 25%                      7.00000    263.500000      2.000000      3.000000
# 50%                      7.00000    512.000000      2.000000      3.000000
# 75%                      7.00000    809.500000      3.000000      4.000000
# max                     21.00000   3560.000000     18.000000     14.000000
#
#         buildingclasstypeid  buildingqualitytypeid  calculatedbathnbr  ...  \
# count                   0.0           33654.000000       52184.000000  ...
# unique                  NaN                    NaN                NaN  ...
# top                     NaN                    NaN                NaN  ...
# freq                    NaN                    NaN                NaN  ...
# mean                    NaN               6.264961           2.305276  ...
# std                     NaN               1.716328           1.018076  ...
# min                     NaN               1.000000           1.000000  ...
# 25%                     NaN               5.000000           2.000000  ...
# 50%                     NaN               6.000000           2.000000  ...
# 75%                     NaN               8.000000           3.000000  ...
# max                     NaN              12.000000          18.000000  ...
#
#         censustractandblock      logerror  transactiondate  \
# count          5.219800e+04  52319.000000            52319
# unique                  NaN           NaN              257
# top                     NaN           NaN       2017-06-30
# freq                    NaN           NaN              809
# mean           6.050245e+13      0.018136              NaN
# std            1.861145e+12      0.176904              NaN
# min            6.037101e+13     -4.655420              NaN
# 25%            6.037401e+13     -0.024702              NaN
# 50%            6.037620e+13      0.006935              NaN
# 75%            6.059042e+13      0.040599              NaN
# max            4.830301e+14      5.262999              NaN
#
#         airconditioningdesc  architecturalstyledesc  buildingclassdesc  \
# count                 13615                      70                0.0
# unique                    4                       5                NaN
# top                 Central            Contemporary                NaN
# freq                  11873                      62                NaN
# mean                    NaN                     NaN                NaN
# std                     NaN                     NaN                NaN
# min                     NaN                     NaN                NaN
# 25%                     NaN                     NaN                NaN
# 50%                     NaN                     NaN                NaN
# 75%                     NaN                     NaN                NaN
# max                     NaN                     NaN                NaN
#
#         heatingorsystemdesc        propertylandusedesc  storydesc  \
# count                 33849                      52319         47
# unique                    9                          1          1
# top                 Central  Single Family Residential   Basement
# freq                  20689                      52319         47
# mean                    NaN                        NaN        NaN
# std                     NaN                        NaN        NaN
# min                     NaN                        NaN        NaN
# 25%                     NaN                        NaN        NaN
# 50%                     NaN                        NaN        NaN
# 75%                     NaN                        NaN        NaN
# max                     NaN                        NaN        NaN
#
#         typeconstructiondesc
# count                     76
# unique                     2
# top                    Frame
# freq                      75
# mean                     NaN
# std                      NaN
# min                      NaN
# 25%                      NaN
# 50%                      NaN
# 75%                      NaN
# max                      NaN
#
# [11 rows x 68 columns]

# %% [markdown]
# >## Handling nulls and missing values:

# %%
#setting up missing values function, to catch only the %%% of data that
#is already there, and not missing.

#checking nulls by columns of the percent of nulls found:

wrangle.nulls_by_columns(df).sort_values(by='percent', ascending=False)
# Out:
#                               count   percent
# buildingclassdesc             52319  1.000000
# buildingclasstypeid           52319  1.000000
# finishedsquarefeet15          52319  1.000000
# finishedsquarefeet13          52319  1.000000
# storytypeid                   52272  0.999102
# basementsqft                  52272  0.999102
# storydesc                     52272  0.999102
# yardbuildingsqft26            52256  0.998796
# architecturalstyletypeid      52249  0.998662
# architecturalstyledesc        52249  0.998662
# typeconstructiondesc          52243  0.998547
# typeconstructiontypeid        52243  0.998547
# fireplaceflag                 52238  0.998452
# finishedsquarefeet6           52154  0.996846
# decktypeid                    51930  0.992565
# pooltypeid10                  51876  0.991533
# poolsizesum                   51454  0.983467
# pooltypeid2                   51248  0.979529
# hashottuborspa                50805  0.971062
# yardbuildingsqft17            50384  0.963015
# taxdelinquencyyear            50251  0.960473
# taxdelinquencyflag            50251  0.960473
# finishedsquarefeet50          47948  0.916455
# finishedfloor1squarefeet      47948  0.916455
# threequarterbathnbr           45602  0.871615
# fireplacecnt                  45086  0.861752
# pooltypeid7                   42329  0.809056
# poolcnt                       41242  0.788280
# airconditioningdesc           38704  0.739769
# airconditioningtypeid         38704  0.739769
# numberofstories               37787  0.722242
# garagecarcnt                  34335  0.656263
# garagetotalsqft               34335  0.656263
# regionidneighborhood          33338  0.637206
# buildingqualitytypeid         18665  0.356754
# unitcnt                       18558  0.354709
# propertyzoningdesc            18558  0.354709
# heatingorsystemtypeid         18470  0.353027
# heatingorsystemdesc           18470  0.353027
# regionidcity                   1036  0.019802
# lotsizesquarefeet               366  0.006996
# finishedsquarefeet12            246  0.004702
# fullbathcnt                     135  0.002580
# calculatedbathnbr               135  0.002580
# censustractandblock             121  0.002313
# yearbuilt                       114  0.002179
# structuretaxvaluedollarcnt       82  0.001567
# calculatedfinishedsquarefeet     81  0.001548
# regionidzip                      26  0.000497
# taxamount                         4  0.000076
# taxvaluedollarcnt                 1  0.000019
# landtaxvaluedollarcnt             1  0.000019
# logerror                          0  0.000000
# transactiondate                   0  0.000000
# propertylandusedesc               0  0.000000
# id                                0  0.000000
# assessmentyear                    0  0.000000
# roomcnt                           0  0.000000
# regionidcounty                    0  0.000000
# rawcensustractandblock            0  0.000000
# parcelid                          0  0.000000
# propertycountylandusecode         0  0.000000
# longitude                         0  0.000000
# latitude                          0  0.000000
# fips                              0  0.000000
# bedroomcnt                        0  0.000000
# bathroomcnt                       0  0.000000
# propertylandusetypeid             0  0.000000

# %%
#now let's look at nulls by rows:
wrangle.nulls_by_rows(df)
# Out:
# n_missing  percent_missing
# 23         0.338235               2
# 24         0.352941              12
# 25         0.367647              11
# 26         0.382353              30
# 27         0.397059             177
# 28         0.411765             390
# 29         0.426471            2527
# 30         0.441176            2199
# 31         0.455882            5989
# 32         0.470588            8885
# 33         0.485294           11967
# 34         0.500000           11157
# 35         0.514706            3469
# 36         0.529412            4138
# 37         0.544118            1020
# 38         0.558824             223
# 39         0.573529              29
# 40         0.588235              15
# 41         0.602941               6
# 42         0.617647               7
# 43         0.632353              10
# 44         0.647059              46
# 45         0.661765               6
# 46         0.676471               1
# 47         0.691176               1
# 48         0.705882               2
# dtype: int64

# %% [markdown]
# ### KEY TAKE AWAYS:
# - For missing values in columns, there is a big difference between regionneighborhood (60% missing) vs building quality type (38%), so I will will set my columns at 60%, since I do want to capture the regionneighborhood.
# - Columns missing values I'll keep at 60% as it looks to be a good split on what is missing.

# %%
#using 60/60 first to see what dataset looks like:
print('Before dropping nulls, %d rows, %d cols' % df.shape)

#dropping the cols & rows that do not meet the 60/60 standard
df = wrangle.handle_missing_values(df, prop_required_column=.6, prop_required_row=.60)
print('After dropping nulls, %d rows, %d cols' % df.shape)
# Out:
# Before dropping nulls, 52319 rows, 68 cols
# After dropping nulls, 52319 rows, 34 cols

# %%
#taking a look at what nulls are left
df.isnull().sum()
# Out:
# id                                  0
# parcelid                            0
# bathroomcnt                         0
# bedroomcnt                          0
# buildingqualitytypeid           18665
# calculatedbathnbr                 135
# calculatedfinishedsquarefeet       81
# finishedsquarefeet12              246
# fips                                0
# fullbathcnt                       135
# heatingorsystemtypeid           18470
# latitude                            0
# longitude                           0
# lotsizesquarefeet                 366
# propertycountylandusecode           0
# propertylandusetypeid               0
# propertyzoningdesc              18558
# rawcensustractandblock              0
# regionidcity                     1036
# regionidcounty                      0
# regionidzip                        26
# roomcnt                             0
# unitcnt                         18558
# yearbuilt                         114
# structuretaxvaluedollarcnt         82
# taxvaluedollarcnt                   1
# assessmentyear                      0
# landtaxvaluedollarcnt               1
# taxamount                           4
# censustractandblock               121
# logerror                            0
# transactiondate                     0
# heatingorsystemdesc             18470
# propertylandusedesc                 0
# dtype: int64

# %% [markdown]
# #### For my next null steps:
#     - I'll drop all the larger null columns.
#     - I'll drop all columns that reiterate information too.
#     - I'll then decide what to do with leftover row nulls

# %%
#creating a function to remove unwanted columns (*may add/change later)

cols_to_remove = ['roomcnt','propertycountylandusecode','propertylandusedesc','propertyzoningdesc','buildingqualitytypeid','heatingorsystemtypeid','unitcnt','heatingorsystemdesc','calculatedbathnbr','id','finishedsquarefeet12','fullbathcnt','structuretaxvaluedollarcnt','landtaxvaluedollarcnt','taxamount','regionidcity','censustractandblock','transactiondate']
df= wrangle.remove_columns(df, cols_to_remove )
df.isnull().sum()
# Out:
# parcelid                          0
# bathroomcnt                       0
# bedroomcnt                        0
# calculatedfinishedsquarefeet     81
# fips                              0
# latitude                          0
# longitude                         0
# lotsizesquarefeet               366
# propertylandusetypeid             0
# rawcensustractandblock            0
# regionidcounty                    0
# regionidzip                      26
# yearbuilt                       114
# taxvaluedollarcnt                 1
# assessmentyear                    0
# logerror                          0
# dtype: int64

# %%
#considering how to handle each low count null...
df.lotsizesquarefeet.mean()
# Out:
# 11323.453910265047

# %%
#looking at value_counts() for each leftover nulls
df.lotsizesquarefeet.value_counts()
# Out:
# 6000.0     873
# 5000.0     413
# 7200.0     306
# 7000.0     285
# 6500.0     272
#           ...
# 18024.0      1
# 20673.0      1
# 4775.0       1
# 9367.0       1
# 47405.0      1
# Name: lotsizesquarefeet, Length: 14292, dtype: int64

# %% [markdown]
# ### KEY TAKEAWAYS:
#
# After thinking about what the nulls might be in these rows, I have decided to drop them as I think for the lotsize and calculatedsqft, these will be dropped anyways once I apply the outlier ranges.

# %%
#dropping the rest of the nulls as losing that many rows out of 52,000 shouldn't affect my data by much

df = wrangle.drop_r_nulls(df)
df.isnull().sum()
# Out:
# parcelid                        0
# bathroomcnt                     0
# bedroomcnt                      0
# calculatedfinishedsquarefeet    0
# fips                            0
# latitude                        0
# longitude                       0
# lotsizesquarefeet               0
# propertylandusetypeid           0
# rawcensustractandblock          0
# regionidcounty                  0
# regionidzip                     0
# yearbuilt                       0
# taxvaluedollarcnt               0
# assessmentyear                  0
# logerror                        0
# dtype: int64

# %% [markdown]
# _______________________________________________________________________________________________________

# %% [markdown]
# >## Looking at Dtypes:

# %%
df.dtypes
# Out:
# parcelid                          int64
# bathroomcnt                     float64
# bedroomcnt                      float64
# calculatedfinishedsquarefeet    float64
# fips                            float64
# latitude                        float64
# longitude                       float64
# lotsizesquarefeet               float64
# propertylandusetypeid           float64
# rawcensustractandblock          float64
# regionidcounty                  float64
# regionidzip                     float64
# yearbuilt                       float64
# taxvaluedollarcnt               float64
# assessmentyear                  float64
# logerror                        float64
# dtype: object

# %% [markdown]
# ### Takeaways:
# - I will leave these as floats.
# - I will leave the object columns alone (and will one-hot-encode fips)

# %% [markdown]
# ## Split the Data:
#
# Using the Train, Validate, Test split function from my Regression project:
# <br>- First, using 80/20 split between Train and Test
# <br>- Then, using 70/30 split and stratifying on fips(county) for even mix of data between each county

# %%
train, validate, test = wrangle.split_data(df)
train
# Out:
#        parcelid  bathroomcnt  bedroomcnt  calculatedfinishedsquarefeet  \
# 34222  11533536          1.0         2.0                         864.0
# 21551  11058331          2.0         3.0                        1243.0
# 39107  14003091          2.0         4.0                        1157.0
# 9029   14208016          2.0         3.0                        1491.0
# 2982   10844442          2.0         4.0                        1843.0
# ...         ...          ...         ...                           ...
# 26973  12685721          2.0         3.0                        1758.0
# 26978  11203451          2.0         3.0                        1560.0
# 6444   13060661          3.0         5.0                        2204.0
# 46771  11516057          6.0         5.0                        5200.0
# 9006   12269556          4.0         7.0                        2891.0
#
#          fips    latitude    longitude  lotsizesquarefeet  \
# 34222  6037.0  33986536.0 -118424309.0             5002.0
# 21551  6037.0  34270033.0 -118492886.0             7795.0
# 39107  6059.0  33794310.0 -117985512.0             7350.0
# 9029   6059.0  33861905.0 -117769542.0             6000.0
# 2982   6037.0  34173761.0 -118454651.0             7202.0
# ...       ...         ...          ...                ...
# 26973  6037.0  33797494.0 -118367130.0            10192.0
# 26978  6037.0  34571891.0 -118081365.0             7062.0
# 6444   6037.0  34031588.0 -117800357.0             7265.0
# 46771  6037.0  33995370.0 -118369954.0             9118.0
# 9006   6037.0  33918641.0 -118236871.0            37346.0
#
#        propertylandusetypeid  rawcensustractandblock  regionidcounty  \
# 34222                  261.0            6.037275e+07          3101.0
# 21551                  261.0            6.037111e+07          3101.0
# 39107                  261.0            6.059088e+07          1286.0
# 9029                   261.0            6.059022e+07          1286.0
# 2982                   261.0            6.037128e+07          3101.0
# ...                      ...                     ...             ...
# 26973                  261.0            6.037670e+07          3101.0
# 26978                  261.0            6.037911e+07          3101.0
# 6444                   261.0            6.037403e+07          3101.0
# 46771                  261.0            6.037703e+07          3101.0
# 9006                   261.0            6.037541e+07          3101.0
#
#        regionidzip  yearbuilt  taxvaluedollarcnt  assessmentyear  logerror
# 34222      96047.0     1950.0           787004.0          2016.0  0.063660
# 21551      96370.0     1953.0           174930.0          2016.0  0.059323
# 39107      97023.0     1954.0           274539.0          2016.0  0.184348
# 9029       97027.0     1975.0           523394.0          2016.0 -0.004648
# 2982       96420.0     1949.0           113758.0          2016.0  0.025679
# ...            ...        ...                ...             ...       ...
# 26973      96121.0     1952.0           140998.0          2016.0 -0.171849
# 26978      97328.0     1965.0           193000.0          2016.0  0.050356
# 6444       96505.0     1965.0           447063.0          2016.0  0.027504
# 46771      96037.0     1958.0          1125682.0          2016.0  0.100770
# 9006       96092.0     1962.0           348019.0          2016.0  0.156133
#
# [29027 rows x 16 columns]

# %% [markdown]
# ## Encoding the Data:
# >#### I want to encode the fips column so that I can use it as a feature for comparing clusters to other features
# -I will start with Los Angeles County as the main predictor for this column, as I already known from using this data that this is the largest county with the most dataset, but later add on encoding for each county, to maybe make into their own models.

# %%
train, validate, test = wrangle.one_hot_encode(train, validate, test)

# %%
#and then I need to turn this new column into an int:
train["is_Los_Angeles"] = train["is_Los_Angeles"].astype(int)
validate["is_Los_Angeles"] = validate["is_Los_Angeles"].astype(int)
test["is_Los_Angeles"] = test["is_Los_Angeles"].astype(int)

train['is_Ventura'] = train['is_Ventura'].astype(int)
validate['is_Ventura'] = validate['is_Ventura'].astype(int)
test['is_Ventura'] = test['is_Ventura'].astype(int)


train['is_Orange'] = train['is_Orange'].astype(int)
validate['is_Orange'] = validate['is_Orange'].astype(int)
test['is_Orange'] = test['is_Orange'].astype(int)

# %% [markdown]
# ## Data Distributions:
# Looking at each feature and its distribution through histograms:

# %%
#create all the histograms:
for col in train.columns:
    plt.figure(figsize=(4,2))
    plt.hist(train[col])
    plt.title(col)
    plt.show()

# %% [markdown]
# ### KEY TAKEAWAYS:
# - I'll add in some outlier ranges to help these distributions look at bit more 'normal'
# - Some columns won't need to be changed (ie. latitude/longitude/zipcode/census/etc)

# %% [markdown]
#  # <mark>Handling Outliers:
#
# ### KEY TAKE AWAYS:
# - Though I think it is important to utilize the CA state laws and requirements for lotsize and property size (as I had below) when determining approaches to handling outliers, I think next time I would also add another element such as including a logerror range to minimize even more of the data in hopes that maybe this would show more results when it came to clustering models.

# %% [markdown]
# >I'll be using the ranges I set in my Regression project to handle outliers:
#
# - Finished Squarefoot Range: 200sqft - 9_000sqft
# - Bedroom Count range: 1-6bd
# - Bathroom Count range:1-6bd
# - Property Tax Value range: 45k - 2.5million
#
# And adding new ranges of:
#
# - Year built: 1950 - 2001
# - Lot Sqft: 2,500 - 435,600 (10acres)...based on CA requirements for minimum and capturing more of Zillow's max clients

# %%
#upclose chart of years to look at the ranges
plt.hist(train.yearbuilt)

#I want to cut out the side 'tails' to really hon into this feature for some hypothesis testing
# Out:
# (array([  18.,  148.,  602., 2230., 2699., 9292., 5426., 3691., 3312.,
#         1609.]),
#  array([1880. , 1893.6, 1907.2, 1920.8, 1934.4, 1948. , 1961.6, 1975.2,
#         1988.8, 2002.4, 2016. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# Creating the outlier ranges:

# %%
train = wrangle.handle_outliers(train)

# %%
#looking at the change of distribution now for features...
#create all the histograms:
for col in train.columns:
    plt.figure(figsize=(4,2))
    plt.hist(train[col])
    plt.title(col)
    plt.show()

# %% [markdown]
# ### Conclusion:
# - most of the features (ie taxvaluedollar, yearbuilt, bed/bath, & calculatedsqft) are right-skewed. I will use a spearman's correlation test when testing the linear relationships.
# - There is more data for Los Angeles county than the other two counties combined.

# %% [markdown]
# ______________________________________________________________________________________________________________

# %% [markdown]
# # Hypothesis Tests:
# ### KEY TAKE AWAYS-
# - County, CalculatedSQft and Yearbuilt all reject null and show strong correlations to logerror.
# - Lotsize however fails to reject null and there is no correlation to logerror.

# %% [markdown]
# ## <i>Hypothesis Testing: Question One
# >### Does logerror differ across county/region of properties?

# %%
#make a scatter plot for is_outlier
sns.scatterplot(data=train, x='longitude', y='latitude', hue='logerror')
# Out:
# <AxesSubplot:xlabel='longitude', ylabel='latitude'>

# %% [markdown]
# ### Taking a look at logerror's size/stats:

# %%
train.logerror.describe().T
# Out:
# count    20875.000000
# mean         0.018810
# std          0.159855
# min         -2.331727
# 25%         -0.021013
# 50%          0.006770
# 75%          0.037311
# max          3.175688
# Name: logerror, dtype: float64

# %% [markdown]
# ### Take away: The region plot shows that the mean of logerrors is happening all across each of our 3 counties...so I would at least say there isn't 'one' county that is only experiencing these log errors...

# %% [markdown]
# I'll use my encoded column 'is_Los_Angeles' in place of fips to t-test as a 2 sample, 2tailed test.

# %% [markdown]
# ### Step One)
#
# alpha = 0.05
#
# - H_0: There is no difference of variance or mean between county and logerror
# - H_a: There is a difference of variance or mean between county and logerror
#
#
# #### Levene Test to check the variance of is_Los_Angeles (county/fips) and logerror
#
# If p-value > .05, we can say that the variances are not significantly different and set the argument in ttest_ind of equal_var to be True. If p-value < .05, we say the variances are NOT equal and set equal_var to be False.

# %%
#Levene Test:
# test the equal variance 
# H0 is that the variances are equal
# our two groups are 1) where train does not equal LA county ==0 and 
# 2) where train does equal LA county == 1

stats.levene(train[train.is_Los_Angeles==0].logerror, 
             train[train.is_Los_Angeles==1].logerror)
# Out:
# LeveneResult(statistic=3.086658331177488, pvalue=0.07895142188751186)

# %% [markdown]
# #### Levene score is significantly less than pvalue 0.05, so equal_var is False

# %% [markdown]
# ### Moving onto a 2-sample, 2-tailed T-test:

# %%
stats.ttest_ind(train[train.is_Los_Angeles==0].logerror, 
                train[train.is_Los_Angeles==1].logerror, 
                equal_var=False
               )
# Out:
# Ttest_indResult(statistic=2.7087702122835595, pvalue=0.006760223884334586)

# %% [markdown]
# ### Conclusion: H_0 is Rejected. There is a difference in mean logerror across county

# %% [markdown]
# _____________________________________________________________

# %% [markdown]
# ## <i>Hypothesis Testing: Question Two
# >### Is there a relationship between yearbuilt and logerror?

# %% [markdown]
# ### I'll do a Spearman's correlation test to see if there is a relationship

# %% [markdown]
# a = 0.05
# - H_0: There is no relationship between logerror and yearbuilt
# - Ha: There is a relationship of mean between logerror and yearbuilt

# %%
#creating a joinplot to see if any linear relationship (also adding in county)

print("Is there a relationship\nbetween yearbuilt and logerror?")
sns.jointplot(x="yearbuilt", y="logerror", data=train, hue = 'fips')
plt.xlabel("Year built")
plt.ylabel("Logerror")
plt.show()
# Out:
# Is there a relationship
# between yearbuilt and logerror?

# %%
stats.spearmanr(train.yearbuilt, train.logerror)
# Out:
# SpearmanrResult(correlation=0.03555923012702954, pvalue=2.762334993927697e-07)

# %% [markdown]
# ### Conclusion: I reject the null hypothesis, as there is a relationship between yearbuilt and logerror

# %% [markdown]
# ___________________________________________________________

# %% [markdown]
# ## <i>Hypothesis Testing: Question Three
# >### Is there a relationship to logerror and calculated squarefeet?
#
# a = 0.05
# - H_0: There is no relationship between calculated sqft and logerror
# - Ha: There is a relationship of mean between calculated sqft and logerror

# %%
#creating a joinplot to see if any linear relationship (also adding in county)

print("Is there a relationship\nbetween Sqft and logerror?")
sns.jointplot(x="calculatedfinishedsquarefeet", y="logerror", data=train, hue = 'fips')
plt.xlabel("Finished Squarefeet")
plt.ylabel("Logerror")
plt.show()
# Out:
# Is there a relationship
# between Sqft and logerror?

# %% [markdown]
# >### Spearman's correlation test to see if there is a relationship between calculated finished sqft and logerror

# %%
stats.spearmanr(train.calculatedfinishedsquarefeet, train.logerror)
# Out:
# SpearmanrResult(correlation=0.08537723537999817, pvalue=4.449157659401028e-35)

# %% [markdown]
# ### Conclusion: There is a relationship found between logerror and Finished Squarefeet. I reject the null hypothesis.

# %%
###Note: I wonder if I put in calculated sqft what the lat/long. map would look like:
#make a scatter plot for is_outlier
sns.scatterplot(data=train, x='longitude', y='latitude', hue='calculatedfinishedsquarefeet')
# Out:
# <AxesSubplot:xlabel='longitude', ylabel='latitude'>

# %% [markdown]
# ### TAKEAWAYS:
# This simple scatterplot isn't showing very much, however I think that once I find some clusters within the clustering section and label those, I'll try bringing these labeled clusters back to the lat/long. chart...

# %% [markdown]
# ## (Added Hypothesis Test after looking at cluster_features below)
# >### Is there a relationship to logerror and lotsize?
#
# a = 0.05
# - H_0: There is no relationship between lot size and logerror
# - Ha: There is a relationship of mean between lot size and logerror

# %%
#checking the shape of lotsize:
plt.hist(train.lotsizesquarefeet)
# Out:
# (array([2.0494e+04, 2.2600e+02, 8.9000e+01, 2.1000e+01, 1.3000e+01,
#         1.5000e+01, 7.0000e+00, 5.0000e+00, 3.0000e+00, 2.0000e+00]),
#  array([  2500. ,  45704.9,  88909.8, 132114.7, 175319.6, 218524.5,
#         261729.4, 304934.3, 348139.2, 391344.1, 434549. ]),
#  <BarContainer object of 10 artists>)

# %%
#right-skewed so using Spearman's corr. test
stats.spearmanr(train.lotsizesquarefeet, train.logerror)
# Out:
# SpearmanrResult(correlation=0.010443677589933325, pvalue=0.1313313772144522)

# %% [markdown]
# ### Conclusion: I accept the null hypothesis, in that there is no relationship between lotsize and logerror

# %% [markdown]
# _____________________________________________________________________________________________________________

# %% [markdown]
# ## Scaling Data
# >  I am creating a scaled version of the data (while keeping unscaled), to use for clustering the features I found within hypothesis testing.

# %%
#looking at the columns I want to use later to look at via clustering
train.columns
# Out:
# Index(['parcelid', 'bathroomcnt', 'bedroomcnt', 'calculatedfinishedsquarefeet',
#        'fips', 'latitude', 'longitude', 'lotsizesquarefeet',
#        'propertylandusetypeid', 'rawcensustractandblock', 'regionidcounty',
#        'regionidzip', 'yearbuilt', 'taxvaluedollarcnt', 'assessmentyear',
#        'logerror', 'is_Los_Angeles', 'is_Ventura', 'is_Orange'],
#       dtype='object')

# %%
#calling in scaled dataframe from wrangle.py function
train_scaled, validate_scaled, test_scaled = wrangle.scale(train, validate, test)

# %% [markdown]
# ________________________________________________________________________________________________________

# %% [markdown]
# # Clustering the Features:
#
# ### KEY FINDINGS:
# Despite the hypothesis tests of each feature of Yearbuilt, Calculated SQft, and County- when these are applied in different ways to cluster models the ANOVA tests do not show any correlation to logerror

# %% [markdown]
# >### <mark>Creating labels for clusters to add to my train dataset to hypothesis test and model with:
#
# ### This first cluster (named cluster_features) I'll create a label that adds in all of the features I tested and am considering when it comes to their relationship to finding the mean of logerror.

# %%
#naming features as X for clustering
X_1 = train_scaled[['calculatedfinishedsquarefeet', 'yearbuilt', 'lotsizesquarefeet','is_Los_Angeles','is_Ventura','is_Orange']]
X_2 = validate_scaled[['calculatedfinishedsquarefeet', 'yearbuilt', 'lotsizesquarefeet','is_Los_Angeles','is_Ventura','is_Orange']]
X_3 = test_scaled[['calculatedfinishedsquarefeet', 'yearbuilt', 'lotsizesquarefeet','is_Los_Angeles','is_Ventura','is_Orange']]

# %%
#creating the KMeans model, fitting the model then predicting with it
kmeans = KMeans(n_clusters=3)
kmeans.fit(X_1)
# Out:
# KMeans(n_clusters=3)

# %%
#storing this predicted cluster of data into original dataframe
train_scaled['cluster_features'] = kmeans.predict(X_1)
validate_scaled['cluster_features'] = kmeans.predict(X_2)
test_scaled['cluster_features'] = kmeans.predict(X_3)

# %%
#Now Visualizing the clusters predicted, using 'cluster' as hue to show the 3 clusters
sns.relplot(data=train_scaled, x='longitude', y='latitude', col= 'cluster_features', hue ='yearbuilt')

# %%
#Now Visualizing the clusters predicted, using 'cluster' as hue to show the 3 clusters
sns.relplot(data=train_scaled, x='longitude', y='latitude', col= 'cluster_features', hue ='calculatedfinishedsquarefeet')

# %%
#Now Visualizing the clusters predicted, using 'cluster' as hue to show the 3 clusters
sns.relplot(data=train_scaled, x='longitude', y='latitude', col= 'cluster_features', hue ='lotsizesquarefeet')

# %% [markdown]
# #### TAKEAWAY:
# I think adding all of these features in the cluster add a lot of noise. I do however see when adding 'hue' there are patterns of yearsbuilt to certain county regions as well as calculated square feet.
#
# The relationship between calculated squarefeet and yearbuilt makes sense as through the years squarefootage of housing I can imagine got larger.
#
# When clustering with the lotsize, there isn't a similar looking pattern happening per county, making me think that this is not a strong predictor of logerror. After adding in a Spearman's hypothesis test above to check on lotsize vs logerror, I can see that this is an accurate prediction--there is no real relationship to lotsize and logerror.

# %% [markdown]
# > ### Adding two clusters to dataset and creating, fitting and apply to models:
# > ## Property Squarefeet and Years Built-Cluster

# %%
#naming features as X for clustering
X_4 = train_scaled[['calculatedfinishedsquarefeet', 'yearbuilt']]
X_5 = validate_scaled[['calculatedfinishedsquarefeet', 'yearbuilt']]
X_6 = test_scaled[['calculatedfinishedsquarefeet', 'yearbuilt']]

# %%
#creating the KMeans model, fitting the model then predicting with it
kmeans = KMeans(n_clusters=3)
kmeans.fit(X_4)

kmeans.predict(X_4)

#storing this predicted cluster of data into original dataframe
train_scaled['cluster_prop_age_size'] = kmeans.predict(X_4)
validate_scaled['cluster_prop_age_size'] = kmeans.predict(X_5)
test_scaled['cluster_prop_age_size'] = kmeans.predict(X_6)

# %%
#Now Visualizing the clusters predicted, using 'cluster' as hue to show the 3 clusters
sns.relplot(data=train_scaled, x='longitude', y='latitude', col= 'cluster_prop_age_size', hue ='yearbuilt')

# %%
#visualizing the clusters
plt.figure(figsize=(5, 5))

for cluster_n in train_scaled.cluster_prop_age_size.sort_values().unique():
    plt.scatter(train_scaled[train_scaled.cluster_prop_age_size == cluster_n].calculatedfinishedsquarefeet, train_scaled[train_scaled.cluster_prop_age_size == cluster_n].yearbuilt, label=f'cluster_{cluster_n}')

plt.legend()
plt.title("K-Means Clusters")
plt.show()

# %%
#using the elbow method to determine if k=3 is best fit:
with plt.style.context('seaborn-whitegrid'):
    plt.figure(figsize=(9, 6))
    pd.Series({k: KMeans(k).fit(X_4).inertia_ for k in range(2, 12)}).plot(marker='x')
    plt.xticks(range(2, 12))
    plt.xlabel('k')
    plt.ylabel('inertia')
    plt.title('Change in inertia as k increases')

# %%
#yes, 3 seems right so now let's plot:
fig, axs = plt.subplots(2, 2, figsize=(13, 13), sharex=True, sharey=True)

for ax, k in zip(axs.ravel(), range(3, 7)):
    clusters = KMeans(k).fit(X_4).predict(X_4)
    ax.scatter(X_4.calculatedfinishedsquarefeet, X_4.yearbuilt, c=clusters)
    ax.set(title='k = {}'.format(k), xlabel='calculatedfinishedsquarefeet', ylabel='yearbuilt')

# %% [markdown]
# ### Conclusion:
# I would actually go with  k = 3 as the clusters are not only capturing a good grouping of section of years and the movement happening in terms of calculated finished square feet but it also has good indicator that it could be helpful to me if I bins years and use them as classifications rather than continous.

# %% [markdown]
# __________________________________________________________________________________________________________________

# %% [markdown]
# ## Creating a Cluster for just is_Los_Angeles

# %%
#Is_Los_Angeles, Sqft, Bathroomcnt
#naming features as X for clustering
X_7= train_scaled[['calculatedfinishedsquarefeet', 'yearbuilt','is_Los_Angeles','bathroomcnt','taxvaluedollarcnt','latitude','longitude']]
X_8= validate_scaled[['calculatedfinishedsquarefeet', 'yearbuilt','is_Los_Angeles','bathroomcnt','taxvaluedollarcnt','latitude','longitude']]
X_9= test_scaled[['calculatedfinishedsquarefeet', 'yearbuilt','is_Los_Angeles','bathroomcnt','taxvaluedollarcnt','latitude','longitude']]

# %%
#creating the KMeans model, fitting the model then predicting with it
kmeans = KMeans(n_clusters=3)
kmeans.fit(X_7)

kmeans.predict(X_7)

#storing this predicted cluster of data into original dataframe
train_scaled['cluster_la'] = kmeans.predict(X_7)
validate_scaled['cluster_la'] = kmeans.predict(X_8)
test_scaled['cluster_la'] = kmeans.predict(X_9)

# %%
#Now Visualizing the clusters predicted, using property value as hue to show the 3 clusters
sns.relplot(data=train_scaled, x='taxvaluedollarcnt', y='calculatedfinishedsquarefeet', col='cluster_la', hue ='is_Los_Angeles')

# %%
#seeing if k is right size for this cluster set:
#using the elbow method to determine if k=3 is best fit:
with plt.style.context('seaborn-whitegrid'):
    plt.figure(figsize=(9, 6))
    pd.Series({k: KMeans(k).fit(X_7).inertia_ for k in range(2, 12)}).plot(marker='x')
    plt.xticks(range(2, 12))
    plt.xlabel('k')
    plt.ylabel('inertia')
    plt.title('Change in inertia as k increases')

# %% [markdown]
# ### Takeaway:
# I don't think this cluster set is very helpful in targeting differences of mean and property predictors, so in turn I don't think that it would be worthwhile in putting in towards looking at logerror.

# %% [markdown]
# >## Cluster for property size and value and location:

# %%
#Is_Los_Angeles, Sqft, Bathroomcnt
#naming features as X for clustering
X_10= train_scaled[['calculatedfinishedsquarefeet', 'taxvaluedollarcnt','latitude','longitude']]
X_11= validate_scaled[['calculatedfinishedsquarefeet', 'taxvaluedollarcnt','latitude','longitude']]
X_12= test_scaled[['calculatedfinishedsquarefeet', 'taxvaluedollarcnt','latitude','longitude']]

# %%
#creating the KMeans model, fitting the model then predicting with it
kmeans = KMeans(n_clusters=3)
kmeans.fit(X_10)

kmeans.predict(X_10)

#storing this predicted cluster of data into original dataframe
train_scaled['cluster_value'] = kmeans.predict(X_10)
validate_scaled['cluster_value'] = kmeans.predict(X_11)
test_scaled['cluster_value'] = kmeans.predict(X_12)

# %%
#Now Visualizing the clusters predicted, using property value as hue to show the 3 clusters
sns.relplot(data=train_scaled, x='latitude', y='longitude', col='cluster_value', hue='taxvaluedollarcnt')

# %%
#In relation to what this cluster looks like as hued 'logerror'
sns.relplot(data=train_scaled, x='latitude', y='longitude', col='cluster_value', hue='logerror')

# %% [markdown]
# ### Takeaway:
#
# I was thinking that possibly the higher the taxvaluedollar count with the cluster_value groupings compared to logerror, would return a pattern in the highest logerror results--however this is not the case.
#
# I may look into using logerror to create my outliers in the future.

# %% [markdown]
# ________________________________________________________________________________________________________

# %% [markdown]
# # Statistical Testing my Cluster models to Logerror:

# %% [markdown]
# I'll be using my best clustering models ('cluster_features' & 'cluster_prop_age_size') to test against logerror to see if there is a relationship connected between the two.
#
# Having looked at the distribution shapes of both logerror AND the new cluster-features column, they both have a 'normalish' shape so I will test using a One-Sample T-test to compare means of each.

# %% [markdown]
# >## <mark>Briefing on this section:
# - Checking shape of logerror, to see if ANOVA testing can be used.
# - ANOVA testing is used, as shape is somewhat normally distributed.
#
# - <b>ANOVA Testing Results on Clusters made:
#     - Cluster_features: Failed to reject null
#     - Cluster_prop_age_size: Failed to reject null
#     - Cluster_LA: Failed to reject null
#     - Cluster_value: Failed to reject null

# %%
#checking the shape of logerror:
plt.hist(train_scaled.logerror)
# Out:
# (array([9.0000e+00, 3.0000e+00, 1.4000e+01, 6.8100e+02, 1.9912e+04,
#         1.8100e+02, 2.6000e+01, 1.8000e+01, 2.8000e+01, 3.0000e+00]),
#  array([-2.33172653, -1.78098508, -1.23024363, -0.67950218, -0.12876073,
#          0.42198072,  0.97272217,  1.52346362,  2.07420507,  2.62494652,
#          3.17568797]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# >## Test One: Does cluster_features (overall features chosen) relate to logerror?
# > ### ANOVA Test on Cluster_features
#
# - a = 0.05
# - H_0: There is no difference of mean between logerror and cluster-features
# - Ha: There is a difference of mean between logerror and cluster-features

# %%
alpha = 0.05

F, p = stats.f_oneway(train_scaled[train_scaled.cluster_features == 0].logerror,
                      train[train_scaled.cluster_features == 1].logerror,
                      train[train_scaled.cluster_features == 2].logerror,
                      train[train_scaled.cluster_features == 3].logerror)

if p < alpha:
    print('We reject the null hypothesis\n')
else:
    print('We fail to reject the null hypothesis\n')

print('Anova Test Results on Cluster_Features')
print('F-value:',F)
print('P-value:',p)
# Out:
# We fail to reject the null hypothesis
#
# Anova Test Results on Cluster_Features
# F-value: nan
# P-value: nan

# %% [markdown]
# >## Test Two: Does cluster_prop_age_size (only property age & sqft) relate to logerror?
# >### ANOVA Test on Clusters of Property age and size
#
# - a = 0.05
# - H_0: There is no difference of mean between logerror and property age/size
# - Ha: There is a difference of mean between logerror and property age/size

# %%
alpha = 0.05

F, p = stats.f_oneway(train_scaled[train_scaled.cluster_prop_age_size == 0].logerror,
                      train[train_scaled.cluster_prop_age_size == 1].logerror,
                      train[train_scaled.cluster_prop_age_size == 2].logerror,
                      train[train_scaled.cluster_prop_age_size == 3].logerror)

if p < alpha:
    print('We reject the null hypothesis\n')
else:
    print('We fail to reject the null hypothesis\n')

print('Anova Test Results on Cluster_Features')
print('F-value:',F)
print('P-value:',p)
# Out:
# We fail to reject the null hypothesis
#
# Anova Test Results on Cluster_Features
# F-value: nan
# P-value: nan

# %% [markdown]
# >## Test Three: Does Cluster_Value (Property value and Sqft) relate to logerror?
# > ### ANOVA Test on Cluster_Value
#
# - a = 0.05
# - H_0: There is no difference of mean between logerror and cluster_value
# - Ha: There is a difference of mean between logerror and cluster_value

# %%
alpha = 0.05

F, p = stats.f_oneway(train_scaled[train_scaled.cluster_value == 0].logerror,
                      train[train_scaled.cluster_value == 1].logerror,
                      train[train_scaled.cluster_value == 2].logerror,
                      train[train_scaled.cluster_value == 3].logerror)

if p < alpha:
    print('We reject the null hypothesis\n')
else:
    print('We fail to reject the null hypothesis\n')

print('Anova Test Results on Cluster_Features')
print('F-value:',F)
print('P-value:',p)
# Out:
# We fail to reject the null hypothesis
#
# Anova Test Results on Cluster_Features
# F-value: nan
# P-value: nan

# %% [markdown]
# >## Test Four: Does Cluster_la (features just on is_LA) relate to logerror?
# > ### ANOVA Test on Cluster_la
#
# - a = 0.05
# - H_0: There is no difference of mean between logerror and cluster_la
# - Ha: There is a difference of mean between logerror and cluster_la

# %%
alpha = 0.05

F, p = stats.f_oneway(train_scaled[train_scaled.cluster_la == 0].logerror,
                      train[train_scaled.cluster_la == 1].logerror,
                      train[train_scaled.cluster_la == 2].logerror,
                      train[train_scaled.cluster_la == 3].logerror)

if p < alpha:
    print('We reject the null hypothesis\n')
else:
    print('We fail to reject the null hypothesis\n')

print('Anova Test Results on Cluster_Features')
print('F-value:',F)
print('P-value:',p)
# Out:
# We fail to reject the null hypothesis
#
# Anova Test Results on Cluster_Features
# F-value: nan
# P-value: nan

# %% [markdown]
# # Explore Phase Takeaways:
#
# Features:
# - Yearbuilt and Calculated Finished Squarefeet had the most visual-correlating patterns and both had higher logerror decimals that other features.
#
# Clusters:
# - None of the clusters I created had any kind of significant results/ No correlation to logerror
# - May need to further look at other groupings of different features, or keeping them 2 features at most.

# %% [markdown]
# ______________________________________________________________________________________________________________

# %% [markdown]
# # Modeling:
#
# ### KEY FINDINGS:
# - Continued forward with Modeling and even used SELECTKBest features (which did include one of the cluster made) to model with.
# - OLS Linear Regression model had the best results in training and validate.
# - However, during Outofsample Test, the OLS model returned back worse results than the baseline.
#
# ### Application:
#
# I'll be utilizing the Regression Models: OLS | LassoLARS | TweedieRegressor | Polynomial Regression

# %%
#looking at the logerror stats to get the mean, median and mode:
print('Log Error Stats\n')
print('average:', round(train.logerror.mean(),6))
print('mode:   ', round(train.logerror.mode()[0],6))
print('median: ', round(train.logerror.median(),6))
# Out:
# Log Error Stats
#
# average: 0.01881
# mode:    0.000727
# median:  0.00677

# %% [markdown]
# >### Creating a baseline:

# %%
# Scale data with prepare function - DROPS LOG ERROR
train_scaled, validate_scaled, test_scaled = wrangle.scale(train, validate, test)

# %%
from model import create_clusters
# Add clusters
train_scaled, validate_scaled, test_scaled = model.create_clusters(train_scaled, validate_scaled, test_scaled)

# %%
# split into X variables and y target

# X is every column except log_error
X_train = train_scaled
# y is only log error, [[]] to keep as df and not series
y_train = train[['logerror']]

# repeat for validate and test
X_validate = validate_scaled
y_validate = validate[['logerror']]

X_test = test_scaled
y_test = test[['logerror']]

# %%
# Creating the baseline to mean of log_error
baseline = train.logerror.mean()

# calculating MSE with y_train (actual) and baseline (extended to same size as df)
baseline_mse = mean_squared_error(y_train, np.full(y_train.shape, baseline))
baseline_rmse = baseline_mse**1/2

print('The Baseline Mean Squared Error:', round(baseline_mse,5))
print('The Baseline Root Mean Squared Error:', round(baseline_rmse,5))
# Out:
# The Baseline Mean Squared Error: 0.02555
# The Baseline Root Mean Squared Error: 0.01278

# %%
# Creating the baseline model:
#We need y_train and y_validate to be dataframes to append the new columns with predicted values. 
y_train = pd.DataFrame(y_train)
y_validate = pd.DataFrame(y_validate)

# 1. Predict logerror_pred_mean
logerror_pred_mean = y_train['logerror'].mean()
y_train['logerror_pred_mean'] = logerror_pred_mean
y_validate['logerror_pred_mean'] = logerror_pred_mean

# 2. compute logerror_pred_median
logerror_pred_median = y_train['logerror'].median()
y_train['logerror_pred_median'] = logerror_pred_median
y_validate['logerror_pred_median'] = logerror_pred_median

# 3. RMSE of logerror_pred_mean
rmse_train = mean_squared_error(y_train.logerror, y_train.logerror_pred_mean)**(1/2)
rmse_validate = mean_squared_error(y_validate.logerror, y_validate.logerror_pred_mean)**(1/2)

print("Baseline RMSE using Mean\nTrain/In-Sample: ", (rmse_train), 
      "\nValidate/Out-of-Sample: ", (rmse_validate))

# 4. RMSE of logerror_pred_median
rmse_train = mean_squared_error(y_train.logerror, y_train.logerror_pred_median)**(1/2)
rmse_validate = mean_squared_error(y_validate.logerror, y_validate.logerror_pred_median)**(1/2)

print("Baseline RMSE using Median\nTrain/In-Sample: ", (rmse_train), 
      "\nValidate/Out-of-Sample: ", (rmse_validate))
# Out:
# Baseline RMSE using Mean
# Train/In-Sample:  0.1598506946389631
# Validate/Out-of-Sample:  0.1704170241810743
# Baseline RMSE using Median
# Train/In-Sample:  0.1603035121371792
# Validate/Out-of-Sample:  0.17074853002637033

# %%
# Using histogram to plot the actual vs predicted means

plt.hist(y_train.logerror, color='blue', alpha=.5, label="Actual Margin of Error")
plt.hist(y_train.logerror_pred_mean, bins=1, color='red', alpha=.5, rwidth=100, label="Predicted Margin of Error - Mean")
plt.hist(y_train.logerror_pred_median, bins=1, color='orange', alpha=.5, rwidth=100, label="Predicted Margin of Error - Median")
plt.xlabel("Log Error")
plt.ylabel("Number of Log Property Transactions")
plt.legend()
plt.show()

# %% [markdown]
# ____________________________________________________________________________________________________________

# %% [markdown]
# >### Creating baseline of all the features for the current predictor of median margin of error (aka logerror)

# %%
#creating a basic Linear Regression model and use all features given:
lm1 = LinearRegression()
lm1.fit(X_train, y_train.logerror)
y_hat = lm1.predict(X_train)

y_train['lm_1'] = y_hat

mean_squared_error(y_train.logerror, y_hat)**(1/2)
# Out:
# 3.5511484650545083e-15

# %% [markdown]
# >### Using SelectK Best feature engineering to find what best features I can fit onto these models:

# %%
# creating LR model
lm = LinearRegression()

# create the rfe object, indicating the ML object (lm) and the number of features to select
rfe = RFE(lm, 6)

# fitting the data using RFE
rfe.fit(X_train,y_train.logerror)  

# get the mask of the columns selected
feature_mask = rfe.support_

# get list of the column names. 
rfe_feature = X_train.iloc[:,feature_mask].columns.tolist()

# %%
# features chosen by SelectKBest
rfe_feature
# Out:
# ['fips',
#  'logerror',
#  'is_Los_Angeles',
#  'is_Ventura',
#  'is_Orange',
#  'cluster_features']

# %% [markdown]
# ______________________________________________________________________________________________________________

# %% [markdown]
# > ### OLS Model:

# %%
#Lets take a look at simple model of features based on the cluster_features model made and compare if against the logerror
X_train1 = train_scaled[['fips',
 'logerror',
 'is_Los_Angeles',
 'is_Ventura',
 'is_Orange',
 'cluster_features']]
y_train1 = train[['logerror']]
y_train1['y_baseline'] = train['logerror'].median()

X_validate1 = validate_scaled[['fips',
 'logerror',
 'is_Los_Angeles',
 'is_Ventura',
 'is_Orange',
 'cluster_features']]
y_validate1 = validate_scaled[['logerror']]
y_validate1['y_baseline'] = validate_scaled['logerror'].median()


# predictor/independent features split into train, test, validate
X_train1 = train_scaled.drop(columns = ['logerror'],axis=1)
X_validate1 = validate_scaled.drop(columns = ['logerror'],axis=1)
X_test1 = test_scaled.drop(columns = ['logerror'],axis=1)

# target variables split into train, test, validate
y_train1 = train_scaled.logerror
y_validate1 = validate_scaled.logerror
y_test1 = test_scaled.logerror

y_train1 = pd.DataFrame(y_train1)
y_validate1 = pd.DataFrame(y_validate1)

# %%
# create the model object
lm = LinearRegression(normalize=True)

# fit the model to our training data. We must specify the column in y_train, 
# since we have converted it to a dataframe from a series! 
lm.fit(X_train1, y_train1.logerror)

# predict train
y_train1['logerror_pred_lm'] = lm.predict(X_train1)

# evaluate: rmse
rmse_train = mean_squared_error(y_train1.logerror, y_train1.logerror_pred_lm)**(1/2)

# predict validate
y_validate1['logerror_pred_lm'] = lm.predict(X_validate1)

# evaluate: rmse
rmse_validate = mean_squared_error(y_validate1.logerror, y_validate1.logerror_pred_lm)**(1/2)

print("RMSE for OLS using LinearRegression\nTraining/In-Sample: ", rmse_train, 
      "\nValidation/Out-of-Sample: ", rmse_validate)
# Out:
# RMSE for OLS using LinearRegression
# Training/In-Sample:  0.159588833618839
# Validation/Out-of-Sample:  0.17064691048275996

# %% [markdown]
# ________________________________________________________________

# %% [markdown]
# ## Onto LassoLars Model:
#     I need to get a new X_train labeled dataset...

# %%
#Lets take a look at simple model of features based on the cluster_features model made and compare if against the logerror
X_train2 = train_scaled[['fips',
 'logerror',
 'is_Los_Angeles',
 'is_Ventura',
 'is_Orange',
 'cluster_features']]
y_train2 = train_scaled[['logerror']]
y_train2['y_baseline'] = train_scaled['logerror'].median()

X_validate2 = validate_scaled[['fips',
 'logerror',
 'is_Los_Angeles',
 'is_Ventura',
 'is_Orange',
 'cluster_features']]
y_validate2 = validate_scaled[['logerror']]
y_validate2['y_baseline'] = validate_scaled['logerror'].median()

# predictor/independent features split into train, test, validate
X_train2 = train_scaled.drop(columns = ['logerror'],axis=1)
X_validate2 = validate_scaled.drop(columns = ['logerror'],axis=1)
X_test2 = test_scaled.drop(columns = ['logerror'],axis=1)

# target variables split into train, test, validate
y_train2 = train_scaled.logerror
y_validate2 = validate_scaled.logerror
y_test2 = test_scaled.logerror

y_train2 = pd.DataFrame(y_train2)
y_validate2 = pd.DataFrame(y_validate2)

# %%
# create the model object
lars = LassoLars(alpha=1.0)

# I first fit the model to the training data. I must specify the column in y_train, 
# since it was converted it to a dataframe from a series! 
lars.fit(X_train2, y_train2.logerror)

# predict train
y_train2['logerror_pred_lars'] = lars.predict(X_train2)

# evaluate: rmse
rmse_train = mean_squared_error(y_train2.logerror, y_train2.logerror_pred_lars)**(1/2)

# predict validate
y_validate2['logerror_pred_lars'] = lars.predict(X_validate2)

# evaluate: rmse
rmse_validate = mean_squared_error(y_validate2.logerror, y_validate2.logerror_pred_lars)**(1/2)

print("RMSE for Lasso + Lars\nTraining/In-Sample: ", rmse_train, 
      "\nValidation/Out-of-Sample: ", rmse_validate)
# Out:
# RMSE for Lasso + Lars
# Training/In-Sample:  0.1598506946389631
# Validation/Out-of-Sample:  0.1704170241810743

# %% [markdown]
# ______________________________________________________________________________

# %% [markdown]
# ## TweedieRegressor (GLM) Model:

# %%
#Lets take a look at simple model of features based on the cluster_features model made and compare if against the logerror
X_train3 = train_scaled[['fips',
 'logerror',
 'is_Los_Angeles',
 'is_Ventura',
 'is_Orange',
 'cluster_features']]
y_train3 = train_scaled[['logerror']]
y_train3['y_baseline'] = train_scaled['logerror'].median()

X_validate3 = validate_scaled[['fips',
 'logerror',
 'is_Los_Angeles',
 'is_Ventura',
 'is_Orange',
 'cluster_features']]
y_validate3 = validate_scaled[['logerror']]
y_validate3['y_baseline'] = validate_scaled['logerror'].median()

# predictor/independent features split into train, test, validate
X_train3 = train_scaled.drop(columns = ['logerror'],axis=1)
X_validate3 = validate_scaled.drop(columns = ['logerror'],axis=1)
X_test3 = test_scaled.drop(columns = ['logerror'],axis=1)

# target variables split into train, test, validate
y_train3 = train_scaled.logerror
y_validate3 = validate_scaled.logerror
y_test3 = test_scaled.logerror

y_train3 = pd.DataFrame(y_train3)
y_validate3 = pd.DataFrame(y_validate3)

# %% [markdown]
# >### Creating the Model:

# %%
# create the model object
glm = TweedieRegressor(power=0, alpha=0.1)

# fit the model to the training data. I must specify the column in y_train, 
# since we have converted it to a dataframe from a series! 
glm.fit(X_train3, y_train3.logerror)

# predict train
y_train3['logerror_pred_glm'] = glm.predict(X_train3)

# evaluate: rmse
rmse_train = mean_squared_error(y_train3.logerror, y_train3.logerror_pred_glm)**(1/2)

# predict validate
y_validate3['logerror_pred_glm'] = glm.predict(X_validate3)

# evaluate: rmse
rmse_validate = mean_squared_error(y_validate3.logerror, y_validate3.logerror_pred_glm)**(1/2)

print("RMSE for GLM using Tweedie, power=0 & alpha=0.1\nTraining/In-Sample: ", rmse_train, 
      "\nValidation/Out-of-Sample: ", rmse_validate)
# Out:
# RMSE for GLM using Tweedie, power=0 & alpha=0.1
# Training/In-Sample:  0.15979488231473155
# Validation/Out-of-Sample:  0.17038219542125532

# %% [markdown]
# ___________________________________________________________________________________

# %% [markdown]
# >## Polynomial Regression: (with 2degrees)

# %%
#Lets take a look at simple model of features based on the cluster_features model made and compare if against the logerror
X_train4 = train_scaled[['fips',
 'logerror',
 'is_Los_Angeles',
 'is_Ventura',
 'is_Orange',
 'cluster_features']]
y_train4 = train_scaled[['logerror']]
y_train4['y_baseline'] = train_scaled['logerror'].median()

X_validate4 = validate_scaled[['fips',
 'logerror',
 'is_Los_Angeles',
 'is_Ventura',
 'is_Orange',
 'cluster_features']]
y_validate4 = validate_scaled[['logerror']]
y_validate4['y_baseline'] = validate_scaled['logerror'].median()

# predictor/independent features split into train, test, validate
X_train4 = train_scaled.drop(columns = ['logerror'],axis=1)
X_validate4 = validate_scaled.drop(columns = ['logerror'],axis=1)
X_test4 = test_scaled.drop(columns = ['logerror'],axis=1)

# target variables split into train, test, validate
y_train4 = train_scaled.logerror
y_validate4 = validate_scaled.logerror
y_test4 = test_scaled.logerror

y_train4 = pd.DataFrame(y_train4)
y_validate4 = pd.DataFrame(y_validate4)

# %%
# make the polynomial features to get a new set of features
pf = PolynomialFeatures(degree=2)

# fit and transform X_train_scaled
X_train_degree2 = pf.fit_transform(X_train4)

# transform X_validate_scaled & X_test_scaled
X_validate_degree2 = pf.transform(X_validate4)
X_test_degree2 = pf.transform(X_test4)

# %%
# create the model object
lm2 = LinearRegression(normalize=True)

# fit the model to our training data. We must specify the column in y_train, 
# since we have converted it to a dataframe from a series! 
lm2.fit(X_train_degree2, y_train4.logerror)

# predict train
y_train4['logerror_pred_lm2'] = lm2.predict(X_train_degree2)

# evaluate: rmse
rmse_train = mean_squared_error(y_train4.logerror, y_train4.logerror_pred_lm2)**(1/2)

# predict validate
y_validate4['logerror_pred_lm2'] = lm2.predict(X_validate_degree2)

# evaluate: rmse
rmse_validate = mean_squared_error(y_validate4.logerror, y_validate4.logerror_pred_lm2)**(1/2)

print("RMSE for Polynomial Model, degrees=2\nTraining/In-Sample: ", rmse_train, 
      "\nValidation/Out-of-Sample: ", rmse_validate)
# Out:
# RMSE for Polynomial Model, degrees=2
# Training/In-Sample:  0.15897115096087963
# Validation/Out-of-Sample:  0.7361553484710551

# %%
# y_validate.head()
plt.figure(figsize=(16,8))
plt.xlim(-.25, .25)
plt.ylim(-.25, .25)
plt.plot(y_validate.logerror, y_validate.logerror_pred_median, alpha=.5, color="gray", label='_nolegend_')
plt.annotate("Baseline: Predict Using Mean", (0.012, 0.012 ))
plt.plot(y_validate.logerror, y_validate.logerror, alpha=.5, color="blue", label='_nolegend_')
plt.annotate("The Ideal Line: Predicted = Actual", (.15, .15), rotation=15.5)


plt.scatter(y_validate4.logerror, y_validate4.logerror_pred_lm2, 
            alpha=.5, color="green", s=100, label="Model 2nd degree Polynomial")
plt.scatter(y_validate1.logerror, y_validate1.logerror_pred_lm, 
            alpha=.5, color="red", s=100, label="Model: LinearRegression")
plt.scatter(y_validate3.logerror, y_validate3.logerror_pred_glm, 
            alpha=.5, color="yellow", s=100, label="Model: TweedieRegressor")



plt.legend()
plt.xlabel("Actual Margin of Error")
plt.ylabel("Predicted Margin of Error")
plt.title("Where are predictions more extreme? More modest?")
# plt.annotate("The polynomial model appears to overreact to noise", (2.0, -10))
# plt.annotate("The OLS model (LinearRegression)\n appears to be most consistent", (15.5, 3))
plt.show()

# %%
#next step: creating a table the shows the results of each RMSE to baseline (of mean/median)

# %%
data = {'Model Used':  ['Baseline','OLS', 'LassoLars', 'GLM','Polynomial-2'],
        'RMSE: Training': ['0.15985', '0.15958','0.15985','0.15979','0.15897'],
        'RMSE: Validate': ['0.17042','0.17064','0.17042','0.17074','0.73615']
        }

df = pd.DataFrame(data)

print (df)
# Out:
#      Model Used RMSE: Training RMSE: Validate
# 0      Baseline        0.15985        0.17042
# 1           OLS        0.15958        0.17064
# 2     LassoLars        0.15985        0.17042
# 3           GLM        0.15979        0.17074
# 4  Polynomial-2        0.15897        0.73615

# %% [markdown]
# _____________________________________________________________________________________________________________

# %% [markdown]
# # Final Model Selection and Results:
#
# I decided to use the OLS model again to test on, as it is performing the best against baseline RMSE.

# %%
y_test1 = pd.DataFrame(y_test1)

# predict on test
y_test1['logerror_pred_lm'] = lm.predict(X_test1)

# evaluate: rmse
rmse_test = mean_squared_error(y_test1.logerror, y_test1.logerror_pred_lm)**(1/2)

print("RMSE for OLS Model using LinearRegression\nOut-of-Sample Performance: ", rmse_test)
# Out:
# RMSE for OLS Model using LinearRegression
# Out-of-Sample Performance:  0.1819916410106547

# %% [markdown]
# # Results: OLS Linear Regression with SelectKFeatures
#
# ### Training InSample: 0.1596
#
# ### Validate OutSample: 0.1706
#
# ### Test OutSample: 0.1819
# ____________________________________________________________________________________________________________________
# ## Takeaways:
#
# - Despite the small improvement the OLS models seemed to have made against the baseline model, once Tested it proved to be less predictive than the current model.

# %% [markdown]
# __________________________________________________________________________________________________________________

# %% [markdown]
# # Next Steps:
#
# ### Personal Steps:
# - Using SelectKBest for selecting Features for clustering first.
# - If using another approach to dropping outliers would have helped model zero in on logerror results. ie Using logerror as the basis for dropping outliers, but binning those as they were creating the large dispersment of errors.
#
# ### Suggestions:
# Geographically, there are definite patterns occuring when it comes to the mean of error for these Zestimates.
# I would suggest our team taking the next two weeks to look at the following steps:
#
# - Bringing in our partnership data of GreatSchools results. Asking them for access or plotting out 2017 schools to compare with the logerrors occuring.
#
# - Finding the missing data or pulling in new data of the 2016-2017 census. By looking at the median age, household size and income I believe we can start to see more of a predictive pattern when it comes to predicting property values.
